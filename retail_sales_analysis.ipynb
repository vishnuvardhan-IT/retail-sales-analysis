# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {
    "Date": pd.date_range(start="2025-01-01", periods=20),
    "Region": np.random.choice(["East", "West", "North", "South"], 20),
    "Product": np.random.choice(["Laptop", "Phone", "Tablet"], 20),
    "Sales": np.random.randint(500, 2000, 20),
    "Quantity": np.random.randint(1, 10, 20)
}

df = pd.DataFrame(data)
df.head()
# Out:
#         Date Region Product  Sales  Quantity
# 0 2025-01-01  North  Tablet    937         8
# 1 2025-01-02   West   Phone    548         3
# 2 2025-01-03   East  Laptop    558         4
# 3 2025-01-04  North   Phone   1542         6
# 4 2025-01-05  North  Tablet   1252         2

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      20 non-null     datetime64[ns]
#  1   Region    20 non-null     object
#  2   Product   20 non-null     object
#  3   Sales     20 non-null     int64
#  4   Quantity  20 non-null     int64
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 932.0+ bytes
#                       Date        Sales   Quantity
# count                   20    20.000000  20.000000
# mean   2025-01-10 12:00:00  1166.900000   4.000000
# min    2025-01-01 00:00:00   548.000000   1.000000
# 25%    2025-01-05 18:00:00   913.750000   2.000000
# 50%    2025-01-10 12:00:00  1249.000000   4.000000
# 75%    2025-01-15 06:00:00  1450.500000   6.000000
# max    2025-01-20 00:00:00  1677.000000   9.000000
# std                    NaN   389.350728   2.554665

# %%
total_sales = df["Sales"].sum()
average_sales = df["Sales"].mean()
total_quantity = df["Quantity"].sum()

print("Total Sales:", total_sales)
print("Average Sales:", round(average_sales,2))
print("Total Quantity Sold:", total_quantity)
# Out:
# Total Sales: 23338
# Average Sales: 1166.9
# Total Quantity Sold: 80

# %%
region_sales = df.groupby("Region")["Sales"].sum().sort_values(ascending=False)
region_sales
# Out:
# Region
# South    7431
# North    6957
# West     4708
# East     4242
# Name: Sales, dtype: int64

# %%
product_sales = df.groupby("Product")["Sales"].sum()
product_sales
# Out:
# Product
# Laptop    4545
# Phone     9742
# Tablet    9051
# Name: Sales, dtype: int64

# %%
region_sales.plot(kind="bar")
plt.title("Total Sales by Region")
plt.xlabel("Region")
plt.ylabel("Sales")
plt.show()

# %%
product_sales.plot(kind="bar")
plt.title("Total Sales by Product")
plt.xlabel("Product")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# # Key Insights
#
# - The highest sales were generated in the West region.
# - Laptop generated the highest revenue.
# - Average sales per transaction is strong.
# - North region needs sales improvement strategy.
